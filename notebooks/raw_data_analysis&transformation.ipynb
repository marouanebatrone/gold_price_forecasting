# %%
import pandas as pd

datasets = {
    "USO": "../raw_data/USO.csv",
    "GLD": "../raw_data/GLD.csv",
    "S&P": "../raw_data/S&P.csv",
    "Gold": "../raw_data/Gold.csv",
    "Silver": "../raw_data/Silver.csv",
    "Copper": "../raw_data/Copper.csv",
    "US_Dollor_Index": "../raw_data/US Dollar Index.csv"
}

dataframes = {name: pd.read_csv(path) for name, path in datasets.items()}

for name, df in dataframes.items():
    print(f"\nDataset: {name}")
    print("-" * 50)
    print("First 5 rows:")
    print(df.head(), "\n")
    print("Info:")
    print(df.info(), "\n")
    print("Missing Values:")
    print(df.isnull().sum(), "\n")
# Out:
# Dataset: USO
# --------------------------------------------------
# First 5 rows:
#          Date  Price   Open   High    Low   Vol. Change %
# 0  11/25/2024  72.14  72.92  73.44  71.97  1.89M   -2.84%
# 1  11/22/2024  74.25  73.10  74.58  72.94  2.57M    1.43%
# 2  11/21/2024  73.20  73.13  73.26  72.39  1.85M    1.64%
# 3  11/20/2024  72.02  72.84  72.84  71.60  1.36M   -0.40%
# 4  11/19/2024  72.31  72.40  72.71  71.40  3.96M    0.33%
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4713 entries, 0 to 4712
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      4713 non-null   object
#  1   Price     4713 non-null   float64
#  2   Open      4713 non-null   float64
#  3   High      4713 non-null   float64
#  4   Low       4713 non-null   float64
#  5   Vol.      4689 non-null   object
#  6   Change %  4713 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 257.9+ KB
# None
#
# Missing Values:
# Date         0
# Price        0
# Open         0
# High         0
# Low          0
# Vol.        24
# Change %     0
# dtype: int64
#
#
# Dataset: GLD
# --------------------------------------------------
# First 5 rows:
#          Date   Price    Open    High     Low   Vol. Change %
# 0  08/23/2024  232.02  231.04  232.73  230.52  5.42M    1.16%
# 1  08/22/2024  229.37  230.35  230.38  228.26  5.77M   -1.20%
# 2  08/21/2024  232.15  231.69  232.87  230.48  5.34M   -0.13%
# 3  08/20/2024  232.46  233.71  234.01  231.13  9.07M    0.37%
# 4  08/19/2024  231.61  230.15  231.78  229.74  5.16M   -0.16%
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      4999 non-null   object
#  1   Price     4999 non-null   float64
#  2   Open      4999 non-null   float64
#  3   High      4999 non-null   float64
#  4   Low       4999 non-null   float64
#  5   Vol.      4973 non-null   object
#  6   Change %  4999 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 273.5+ KB
# None
#
# Missing Values:
# Date         0
# Price        0
# Open         0
# High         0
# Low          0
# Vol.        26
# Change %     0
# dtype: int64
#
#
# Dataset: S&P
# --------------------------------------------------
# First 5 rows:
#          Date     Price      Open      High       Low   Vol. Change %
# 0  11/25/2024  5,983.43  6,008.70  6,020.57  5,964.02  0.00K    0.24%
# 1  11/22/2024  5,969.34  5,944.36  5,972.90  5,944.36  0.00K    0.35%
# 2  11/21/2024  5,948.71  5,940.58  5,963.32  5,887.26  0.00K    0.53%
# 3  11/20/2024  5,917.11  5,914.34  5,920.67  5,860.56  0.00K    0.00%
# 4  11/19/2024  5,916.98  5,870.05  5,923.51  5,855.29  0.00K    0.40%
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6265 entries, 0 to 6264
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      6265 non-null   object
#  1   Price     6265 non-null   object
#  2   Open      6265 non-null   object
#  3   High      6265 non-null   object
#  4   Low       6265 non-null   object
#  5   Vol.      6 non-null      object
#  6   Change %  6265 non-null   object
# dtypes: object(7)
# memory usage: 342.7+ KB
# None
#
# Missing Values:
# Date           0
# Price          0
# Open           0
# High           0
# Low            0
# Vol.        6259
# Change %       0
# dtype: int64
#
#
# Dataset: Gold
# --------------------------------------------------
# First 5 rows:
#          Date     Price      Open      High       Low    Vol. Change %
# 0  11/25/2024  2,654.10  2,746.40  2,746.85  2,650.10     NaN   -3.37%
# 1  11/24/2024  2,746.55  2,745.25  2,747.95  2,717.00     NaN    0.34%
# 2  11/22/2024  2,737.20  2,695.90  2,743.30  2,694.50  74.54K    1.40%
# 3  11/21/2024  2,699.30  2,677.30  2,700.70  2,675.50  67.07K    0.89%
# 4  11/20/2024  2,675.60  2,659.20  2,682.80  2,645.50  46.86K    0.79%
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6311 entries, 0 to 6310
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      6311 non-null   object
#  1   Price     6311 non-null   object
#  2   Open      6311 non-null   object
#  3   High      6311 non-null   object
#  4   Low       6311 non-null   object
#  5   Vol.      6297 non-null   object
#  6   Change %  6311 non-null   object
# dtypes: object(7)
# memory usage: 345.3+ KB
# None
#
# Missing Values:
# Date         0
# Price        0
# Open         0
# High         0
# Low          0
# Vol.        14
# Change %     0
# dtype: int64
#
#
# Dataset: Silver
# --------------------------------------------------
# First 5 rows:
#          Date   Price    Open    High     Low    Vol. Change %
# 0  11/25/2024  30.633  31.900  31.913  30.540     NaN   -3.97%
# 1  11/24/2024  31.900  31.883  31.980  31.730     NaN    0.39%
# 2  11/22/2024  31.776  31.315  31.905  31.240  26.59K    1.27%
# 3  11/21/2024  31.379  31.370  31.810  31.145  22.97K   -0.17%
# 4  11/20/2024  31.434  31.735  31.850  31.295  13.81K   -0.82%
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6379 entries, 0 to 6378
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      6379 non-null   object
#  1   Price     6379 non-null   float64
#  2   Open      6379 non-null   float64
#  3   High      6379 non-null   float64
#  4   Low       6379 non-null   float64
#  5   Vol.      6335 non-null   object
#  6   Change %  6379 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 349.0+ KB
# None
#
# Missing Values:
# Date         0
# Price        0
# Open         0
# High         0
# Low          0
# Vol.        44
# Change %     0
# dtype: int64
#
#
# Dataset: Copper
# --------------------------------------------------
# First 5 rows:
#          Date   Price    Open    High     Low    Vol. Change %
# 0  12/06/2024  4.1965  4.1995  4.2530  4.1815     NaN    0.10%
# 1  12/05/2024  4.1925  4.1970  4.2335  4.1755  35.41K   -0.21%
# 2  12/04/2024  4.2015  4.1970  4.2155  4.1700  43.59K   -0.01%
# 3  12/03/2024  4.2020  4.1390  4.2610  4.1120  84.84K    1.73%
# 4  12/02/2024  4.1305  4.1430  4.1475  4.0815  47.45K   -0.23%
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6353 entries, 0 to 6352
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      6353 non-null   object
#  1   Price     6353 non-null   float64
#  2   Open      6353 non-null   float64
#  3   High      6353 non-null   float64
#  4   Low       6353 non-null   float64
#  5   Vol.      6265 non-null   object
#  6   Change %  6353 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 347.6+ KB
# None
#
# Missing Values:
# Date         0
# Price        0
# Open         0
# High         0
# Low          0
# Vol.        88
# Change %     0
# dtype: int64
#
#
# Dataset: US_Dollor_Index
# --------------------------------------------------
# First 5 rows:
#          Date    Price     Open     High      Low    Vol. Change %
# 0  12/06/2024  106.039  105.780  106.150  105.400  18.95K    0.32%
# 1  12/05/2024  105.701  106.305  106.360  105.685  19.94K   -0.55%
# 2  12/04/2024  106.290  106.425  106.700  106.065  21.10K   -0.05%
# 3  12/03/2024  106.340  106.460  106.580  106.065  20.93K   -0.08%
# 4  12/02/2024  106.423  105.820  106.725  105.820  24.59K    0.56%
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6403 entries, 0 to 6402
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      6403 non-null   object
#  1   Price     6403 non-null   float64
#  2   Open      6403 non-null   float64
#  3   High      6403 non-null   float64
#  4   Low       6403 non-null   float64
#  5   Vol.      6375 non-null   object
#  6   Change %  6403 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 350.3+ KB
# None
#
# Missing Values:
# Date         0
# Price        0
# Open         0
# High         0
# Low          0
# Vol.        28
# Change %     0
# dtype: int64

# %% [markdown]
# As we can see the Vol. column (the volumn that such a thing traded in a day) is the only that contains missing values and it won't add a significant value in our foecasting, so let's just delete it.

# %% [markdown]
# # Data preparation

# %%
# Dropping the 'Vol.' column from all datasets
for name, df in dataframes.items():
    if 'Vol.' in df.columns:
        df.drop(columns=['Vol.'], inplace=True)

# %%
for name, df in dataframes.items():
    print(f"{name} dataset")
    print(df.isnull().sum(), "\n")
# Out:
# USO dataset
# Date        0
# Price       0
# Open        0
# High        0
# Low         0
# Change %    0
# dtype: int64
#
# GLD dataset
# Date        0
# Price       0
# Open        0
# High        0
# Low         0
# Change %    0
# dtype: int64
#
# S&P dataset
# Date        0
# Price       0
# Open        0
# High        0
# Low         0
# Change %    0
# dtype: int64
#
# Gold dataset
# Date        0
# Price       0
# Open        0
# High        0
# Low         0
# Change %    0
# dtype: int64
#
# Silver dataset
# Date        0
# Price       0
# Open        0
# High        0
# Low         0
# Change %    0
# dtype: int64
#
# Copper dataset
# Date        0
# Price       0
# Open        0
# High        0
# Low         0
# Change %    0
# dtype: int64
#
# US_Dollor_Index dataset
# Date        0
# Price       0
# Open        0
# High        0
# Low         0
# Change %    0
# dtype: int64

# %% [markdown]
# Now our datasets have zero missing values

# %% [markdown]
# Now let's change prices columns type from object to numeric and date columns from object to datetime

# %%
for df_name, df in dataframes.items():
    for col in ['Price', 'Open', 'High', 'Low']:
        if col in df.columns:
            df[col] = df[col].replace({',': ''}, regex=True)  # Removing commas from price columns
            df[col] = pd.to_numeric(df[col], errors='coerce')  
    
    if 'Change %' in df.columns:
        df['Change %'] = df['Change %'].replace({'%': ''}, regex=True)  
        df['Change %'] = pd.to_numeric(df['Change %'], errors='coerce') 
    df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')


    print("")  
    print(f"DataFrame: {df_name}")
    print(df.head()) 
    print("Dataframe info:")
    print(df.info(), "\n")
# Out:
# DataFrame: USO
#         Date  Price   Open   High    Low  Change %
# 0 2024-11-25  72.14  72.92  73.44  71.97     -2.84
# 1 2024-11-22  74.25  73.10  74.58  72.94      1.43
# 2 2024-11-21  73.20  73.13  73.26  72.39      1.64
# 3 2024-11-20  72.02  72.84  72.84  71.60     -0.40
# 4 2024-11-19  72.31  72.40  72.71  71.40      0.33
# Dataframe info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4713 entries, 0 to 4712
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      4713 non-null   datetime64[ns]
#  1   Price     4713 non-null   float64
#  2   Open      4713 non-null   float64
#  3   High      4713 non-null   float64
#  4   Low       4713 non-null   float64
#  5   Change %  4713 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 221.1 KB
# None
#
#
# DataFrame: GLD
#         Date   Price    Open    High     Low  Change %
# 0 2024-08-23  232.02  231.04  232.73  230.52      1.16
# 1 2024-08-22  229.37  230.35  230.38  228.26     -1.20
# 2 2024-08-21  232.15  231.69  232.87  230.48     -0.13
# 3 2024-08-20  232.46  233.71  234.01  231.13      0.37
# 4 2024-08-19  231.61  230.15  231.78  229.74     -0.16
# Dataframe info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      4999 non-null   datetime64[ns]
#  1   Price     4999 non-null   float64
#  2   Open      4999 non-null   float64
#  3   High      4999 non-null   float64
#  4   Low       4999 non-null   float64
#  5   Change %  4999 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 234.5 KB
# None
#
#
# DataFrame: S&P
#         Date    Price     Open     High      Low  Change %
# 0 2024-11-25  5983.43  6008.70  6020.57  5964.02      0.24
# 1 2024-11-22  5969.34  5944.36  5972.90  5944.36      0.35
# 2 2024-11-21  5948.71  5940.58  5963.32  5887.26      0.53
# 3 2024-11-20  5917.11  5914.34  5920.67  5860.56      0.00
# 4 2024-11-19  5916.98  5870.05  5923.51  5855.29      0.40
# Dataframe info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6265 entries, 0 to 6264
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      6265 non-null   datetime64[ns]
#  1   Price     6265 non-null   float64
#  2   Open      6265 non-null   float64
#  3   High      6265 non-null   float64
#  4   Low       6265 non-null   float64
#  5   Change %  6265 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 293.8 KB
# None
#
#
# DataFrame: Gold
#         Date    Price     Open     High     Low  Change %
# 0 2024-11-25  2654.10  2746.40  2746.85  2650.1     -3.37
# 1 2024-11-24  2746.55  2745.25  2747.95  2717.0      0.34
# 2 2024-11-22  2737.20  2695.90  2743.30  2694.5      1.40
# 3 2024-11-21  2699.30  2677.30  2700.70  2675.5      0.89
# 4 2024-11-20  2675.60  2659.20  2682.80  2645.5      0.79
# Dataframe info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6311 entries, 0 to 6310
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      6311 non-null   datetime64[ns]
#  1   Price     6311 non-null   float64
#  2   Open      6311 non-null   float64
#  3   High      6311 non-null   float64
#  4   Low       6311 non-null   float64
#  5   Change %  6311 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 296.0 KB
# None
#
#
# DataFrame: Silver
#         Date   Price    Open    High     Low  Change %
# 0 2024-11-25  30.633  31.900  31.913  30.540     -3.97
# 1 2024-11-24  31.900  31.883  31.980  31.730      0.39
# 2 2024-11-22  31.776  31.315  31.905  31.240      1.27
# 3 2024-11-21  31.379  31.370  31.810  31.145     -0.17
# 4 2024-11-20  31.434  31.735  31.850  31.295     -0.82
# Dataframe info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6379 entries, 0 to 6378
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      6379 non-null   datetime64[ns]
#  1   Price     6379 non-null   float64
#  2   Open      6379 non-null   float64
#  3   High      6379 non-null   float64
#  4   Low       6379 non-null   float64
#  5   Change %  6379 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 299.1 KB
# None
#
#
# DataFrame: Copper
#         Date   Price    Open    High     Low  Change %
# 0 2024-12-06  4.1965  4.1995  4.2530  4.1815      0.10
# 1 2024-12-05  4.1925  4.1970  4.2335  4.1755     -0.21
# 2 2024-12-04  4.2015  4.1970  4.2155  4.1700     -0.01
# 3 2024-12-03  4.2020  4.1390  4.2610  4.1120      1.73
# 4 2024-12-02  4.1305  4.1430  4.1475  4.0815     -0.23
# Dataframe info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6353 entries, 0 to 6352
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      6353 non-null   datetime64[ns]
#  1   Price     6353 non-null   float64
#  2   Open      6353 non-null   float64
#  3   High      6353 non-null   float64
#  4   Low       6353 non-null   float64
#  5   Change %  6353 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 297.9 KB
# None
#
#
# DataFrame: US_Dollor_Index
#         Date    Price     Open     High      Low  Change %
# 0 2024-12-06  106.039  105.780  106.150  105.400      0.32
# 1 2024-12-05  105.701  106.305  106.360  105.685     -0.55
# 2 2024-12-04  106.290  106.425  106.700  106.065     -0.05
# 3 2024-12-03  106.340  106.460  106.580  106.065     -0.08
# 4 2024-12-02  106.423  105.820  106.725  105.820      0.56
# Dataframe info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6403 entries, 0 to 6402
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      6403 non-null   datetime64[ns]
#  1   Price     6403 non-null   float64
#  2   Open      6403 non-null   float64
#  3   High      6403 non-null   float64
#  4   Low       6403 non-null   float64
#  5   Change %  6403 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 300.3 KB
# None

# %% [markdown]
# Let's see now the date range for each dataset

# %%
for name, df in dataframes.items():
    df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')
    
    min_date = df['Date'].min()
    max_date = df['Date'].max()
    
    print(f"\n{name} Dataset Date Range:")
    print(f"Start Date: {min_date}")
    print(f"End Date: {max_date}")
    
    expected_row_count = (max_date - min_date).days + 1
    
    actual_row_count = df.shape[0]
    missing_rows = expected_row_count - actual_row_count
    
    print(f"{name} dataset:")
    print(f"  - Expected rows: {expected_row_count}")
    print(f"  - Actual rows: {actual_row_count}")
    print(f"  - Missing rows: {missing_rows}")
# Out:
# USO Dataset Date Range:
# Start Date: 2006-04-11 00:00:00
# End Date: 2024-11-25 00:00:00
# USO dataset:
#   - Expected rows: 6804
#   - Actual rows: 4713
#   - Missing rows: 2091
#
# GLD Dataset Date Range:
# Start Date: 2004-11-19 00:00:00
# End Date: 2024-08-23 00:00:00
# GLD dataset:
#   - Expected rows: 7218
#   - Actual rows: 4999
#   - Missing rows: 2219
#
# S&P Dataset Date Range:
# Start Date: 2000-01-03 00:00:00
# End Date: 2024-11-25 00:00:00
# S&P dataset:
#   - Expected rows: 9094
#   - Actual rows: 6265
#   - Missing rows: 2829
#
# Gold Dataset Date Range:
# Start Date: 2000-01-04 00:00:00
# End Date: 2024-11-25 00:00:00
# Gold dataset:
#   - Expected rows: 9093
#   - Actual rows: 6311
#   - Missing rows: 2782
#
# Silver Dataset Date Range:
# Start Date: 2000-01-04 00:00:00
# End Date: 2024-11-25 00:00:00
# Silver dataset:
#   - Expected rows: 9093
#   - Actual rows: 6379
#   - Missing rows: 2714
#
# Copper Dataset Date Range:
# Start Date: 2000-01-04 00:00:00
# End Date: 2024-12-06 00:00:00
# Copper dataset:
#   - Expected rows: 9104
#   - Actual rows: 6353
#   - Missing rows: 2751
#
# US_Dollor_Index Dataset Date Range:
# Start Date: 2000-01-03 00:00:00
# End Date: 2024-12-06 00:00:00
# US_Dollor_Index dataset:
#   - Expected rows: 9105
#   - Actual rows: 6403
#   - Missing rows: 2702

# %% [markdown]
# As we see the datasets have different date ranges and they have missing dates, let's fill the missing dates with linear interpolation for each dataset.

# %%
for name, df in dataframes.items():
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)

    df_resampled = df.resample('D').asfreq()  
    df_interpolated = df_resampled.interpolate(method='linear')  # Linear interpolation

    dataframes[name] = df_interpolated.reset_index() 

    print(f"{name} - After Interpolation:")
    print(dataframes[name].head())
# Out:
# USO - After Interpolation:
#         Date   Price    Open    High     Low  Change %
# 0 2006-04-11  545.60  546.56  547.12  538.40    0.2600
# 1 2006-04-12  542.72  545.76  550.48  542.48   -0.5300
# 2 2006-04-13  550.56  540.00  551.92  539.20    1.4400
# 3 2006-04-14  552.50  543.40  553.74  541.76    1.4325
# 4 2006-04-15  554.44  546.80  555.56  544.32    1.4250
# GLD - After Interpolation:
#         Date      Price       Open       High    Low  Change %
# 0 2004-11-19  44.780000  44.490000  44.920000  44.47  0.900000
# 1 2004-11-20  44.836667  44.576667  44.936667  44.56  0.726667
# 2 2004-11-21  44.893333  44.663333  44.953333  44.65  0.553333
# 3 2004-11-22  44.950000  44.750000  44.970000  44.74  0.380000
# 4 2004-11-23  44.750000  44.880000  44.920000  44.72 -0.440000
# S&P - After Interpolation:
#         Date   Price    Open    High     Low  Change %
# 0 2000-01-03  1455.2  1469.2  1478.0  1438.4     -0.95
# 1 2000-01-04  1399.4  1455.2  1455.2  1397.4     -3.83
# 2 2000-01-05  1402.1  1399.4  1413.3  1377.7      0.19
# 3 2000-01-06  1403.5  1402.1  1411.9  1392.0      0.10
# 4 2000-01-07  1441.5  1403.5  1441.5  1400.5      2.71
# Gold - After Interpolation:
#         Date       Price        Open   High         Low  Change %
# 0 2000-01-04  283.700000  289.500000  289.5  280.000000 -2.040000
# 1 2000-01-05  282.100000  283.700000  285.0  281.000000 -0.560000
# 2 2000-01-06  282.400000  281.600000  282.8  280.200000  0.110000
# 3 2000-01-07  282.900000  282.500000  284.5  282.000000  0.180000
# 4 2000-01-08  282.833333  282.466667  284.3  281.933333  0.096667
# Silver - After Interpolation:
#         Date     Price      Open   High       Low  Change %
# 0 2000-01-04  5.375000  5.420000  5.420  5.320000 -1.430000
# 1 2000-01-05  5.210000  5.375000  5.380  5.160000 -3.070000
# 2 2000-01-06  5.167000  5.205000  5.215  5.150000 -0.830000
# 3 2000-01-07  5.195000  5.170000  5.215  5.150000  0.540000
# 4 2000-01-08  5.193333  5.176667  5.220  5.156667  0.326667
# Copper - After Interpolation:
#         Date   Price    Open      High       Low  Change %
# 0 2000-01-04  0.8480  0.8615  0.862000  0.845000 -1.740000
# 1 2000-01-05  0.8565  0.8450  0.859000  0.838000  1.000000
# 2 2000-01-06  0.8530  0.8560  0.856500  0.848000 -0.410000
# 3 2000-01-07  0.8540  0.8530  0.862500  0.849500  0.120000
# 4 2000-01-08  0.8515  0.8530  0.859833  0.846333 -0.213333
# US_Dollor_Index - After Interpolation:
#         Date   Price    Open    High     Low  Change %
# 0 2000-01-03   99.89  101.39  101.57   99.85     -1.62
# 1 2000-01-04  100.10  100.18  100.37   99.70      0.21
# 2 2000-01-05  100.05  100.09  100.16   99.40     -0.05
# 3 2000-01-06  100.34  100.05  100.48   99.60      0.29
# 4 2000-01-07  100.50  100.18  100.70  100.16      0.16

# %% [markdown]
# Let's now verify that there aren't missing dates after we did linear interpolation

# %%
for name, df in dataframes.items():
    df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')
    
    min_date = df['Date'].min()
    max_date = df['Date'].max()
    
    print(f"\n{name} Dataset Date Range:")
    print(f"Start Date: {min_date}")
    print(f"End Date: {max_date}")
    
    expected_row_count = (max_date - min_date).days + 1
    
    actual_row_count = df.shape[0]
    missing_rows = expected_row_count - actual_row_count
    
    print(f"{name} dataset:")
    print(f"  - Expected rows: {expected_row_count}")
    print(f"  - Actual rows: {actual_row_count}")
    print(f"  - Missing rows: {missing_rows}")
# Out:
# USO Dataset Date Range:
# Start Date: 2006-04-11 00:00:00
# End Date: 2024-11-25 00:00:00
# USO dataset:
#   - Expected rows: 6804
#   - Actual rows: 6804
#   - Missing rows: 0
#
# GLD Dataset Date Range:
# Start Date: 2004-11-19 00:00:00
# End Date: 2024-08-23 00:00:00
# GLD dataset:
#   - Expected rows: 7218
#   - Actual rows: 7218
#   - Missing rows: 0
#
# S&P Dataset Date Range:
# Start Date: 2000-01-03 00:00:00
# End Date: 2024-11-25 00:00:00
# S&P dataset:
#   - Expected rows: 9094
#   - Actual rows: 9094
#   - Missing rows: 0
#
# Gold Dataset Date Range:
# Start Date: 2000-01-04 00:00:00
# End Date: 2024-11-25 00:00:00
# Gold dataset:
#   - Expected rows: 9093
#   - Actual rows: 9093
#   - Missing rows: 0
#
# Silver Dataset Date Range:
# Start Date: 2000-01-04 00:00:00
# End Date: 2024-11-25 00:00:00
# Silver dataset:
#   - Expected rows: 9093
#   - Actual rows: 9093
#   - Missing rows: 0
#
# Copper Dataset Date Range:
# Start Date: 2000-01-04 00:00:00
# End Date: 2024-12-06 00:00:00
# Copper dataset:
#   - Expected rows: 9104
#   - Actual rows: 9104
#   - Missing rows: 0
#
# US_Dollor_Index Dataset Date Range:
# Start Date: 2000-01-03 00:00:00
# End Date: 2024-12-06 00:00:00
# US_Dollor_Index dataset:
#   - Expected rows: 9105
#   - Actual rows: 9105
#   - Missing rows: 0

# %% [markdown]
# # Feature selection and anlysis

# %% [markdown]
# Correlation analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

correlation_results = {}

for name, df in dataframes.items():
    numeric_df = df.drop(columns=["Date"])
    
    corr_matrix = numeric_df.corr()
    
    correlation_results[name] = corr_matrix
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(corr_matrix, annot=True, fmt=".4f", cmap="coolwarm", cbar=True, square=True)
    plt.title(f"Pearson correlation heatmap - {name} Dataset")
    plt.show()

# %% [markdown]
# In all datasets, Price, Open, High, and Low are highly correlated (values close to 1).
# And change % is very low correlated to these prices and to Price column in particular, so let's just work with Price column for each dataset.

# %% [markdown]
# But before we combine these prices columns into one single dataset, we have to decide which date range to go with. So let's see the correlation between these price columns to choose which ones to keep.

# %%
# In order to calculate correlations between Price columns, they should be in the same date range
min_date = max(df['Date'].min() for df in dataframes.values())
max_date = min(df['Date'].max() for df in dataframes.values())

print(f"Datasets will be aligned to these common date range: {min_date.date()} to {max_date.date()}")
# Out:
# Datasets will be aligned to these common date range: 2006-04-11 to 2024-08-23

# %%
common_date_dataframes = dataframes
for name, df in dataframes.items():
    common_date_dataframes[name] = df[(df['Date'] >= min_date) & (df['Date'] <= max_date)]

# %%
for name, df in common_date_dataframes.items():
    min_date = df['Date'].min()
    max_date = df['Date'].max()
    
    print(f"\n{name} Dataset Date Range:")
    print(f"Start Date: {min_date}")
    print(f"End Date: {max_date}")
# Out:
# USO Dataset Date Range:
# Start Date: 2006-04-11 00:00:00
# End Date: 2024-08-23 00:00:00
#
# GLD Dataset Date Range:
# Start Date: 2006-04-11 00:00:00
# End Date: 2024-08-23 00:00:00
#
# S&P Dataset Date Range:
# Start Date: 2006-04-11 00:00:00
# End Date: 2024-08-23 00:00:00
#
# Gold Dataset Date Range:
# Start Date: 2006-04-11 00:00:00
# End Date: 2024-08-23 00:00:00
#
# Silver Dataset Date Range:
# Start Date: 2006-04-11 00:00:00
# End Date: 2024-08-23 00:00:00
#
# Copper Dataset Date Range:
# Start Date: 2006-04-11 00:00:00
# End Date: 2024-08-23 00:00:00
#
# US_Dollor_Index Dataset Date Range:
# Start Date: 2006-04-11 00:00:00
# End Date: 2024-08-23 00:00:00

# %%
price_data = {name: df[['Date', 'Price']].rename(columns={'Price': f'{name}_Price'}).set_index('Date') 
              for name, df in common_date_dataframes.items()}

# Combining
combined_prices = pd.concat(price_data.values(), axis=1)

# %%
combined_prices
# Out:
#             USO_Price  GLD_Price  S&P_Price  Gold_Price  Silver_Price  \
# Date
# 2006-04-11     545.60    59.0100    1286.60     599.400       12.6000
# 2006-04-12     542.72    59.4300    1288.10     601.300       12.6630
# 2006-04-13     550.56    59.5000    1289.10     600.100       12.8550
# 2006-04-14     552.50    59.8975    1288.15     604.775       12.9825
# 2006-04-15     554.44    60.2950    1287.20     609.450       13.1100
# ...               ...        ...        ...         ...           ...
# 2024-08-19      74.38   231.6100    5608.25    2541.300       29.7320
# 2024-08-20      73.83   232.4600    5597.12    2550.600       29.9530
# 2024-08-21      72.60   232.1500    5620.85    2547.500       29.9710
# 2024-08-22      73.58   229.3700    5570.64    2516.700       29.4710
# 2024-08-23      75.55   232.0200    5634.61    2546.300       30.2560
#
#             Copper_Price  US_Dollor_Index_Price
# Date
# 2006-04-11      2.720500                89.1500
# 2006-04-12      2.769500                89.3100
# 2006-04-13      2.811500                89.3700
# 2006-04-14      2.831875                89.1175
# 2006-04-15      2.852250                88.8650
# ...                  ...                    ...
# 2024-08-19      4.220000               101.7310
# 2024-08-20      4.201000               101.2990
# 2024-08-21      4.226500               100.9100
# 2024-08-22      4.186000               101.3990
# 2024-08-23      4.245000               100.6060
#
# [6710 rows x 7 columns]

# %%
price_corr = combined_prices.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(price_corr, annot=True, cmap='coolwarm', fmt=".4f", linewidths=0.5)
plt.title("Pearson correlation heatmap for prices")
plt.show()

# %% [markdown]
# We can see a high Correlations Between Features:
# - GLD_Price is highly correlated with Gold_Price (0.998) and Silver_Price (0.743).
# - S&P_Price and US_Dollor_Index_Price have a strong correlation (0.786).
#
# Let's calculate Variance inflation factor (VIF) to detect multicollinearity.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

X = combined_prices.drop(columns=['Gold_Price']) 
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif_data)
# Out:
#                  feature         VIF
# 0              USO_Price    8.965088
# 1              GLD_Price  171.408804
# 2              S&P_Price   37.566707
# 3           Silver_Price  101.844100
# 4           Copper_Price   97.999815
# 5  US_Dollor_Index_Price   35.806122

# %% [markdown]
# We got (VIF = 171.41) for GLD_Price , which is extremely high multicollinearity, likely because it's almost perfectly correlated with Gold_Price (the target).
#
# So let's Drop GLD_Price since it has the highest VIF and is almost perfectly correlated with the target.

# %%
combined_prices.drop(columns=['GLD_Price'], inplace=True)

# %% [markdown]
# Recalculating the VIF

# %%
X = combined_prices.drop(columns=['Gold_Price'])  
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif_data)
# Out:
#                  feature        VIF
# 0              USO_Price   8.821192
# 1              S&P_Price  22.721006
# 2           Silver_Price  26.832292
# 3           Copper_Price  91.648294
# 4  US_Dollor_Index_Price  22.099918

# %% [markdown]
# Let's remove the Copper_Price feature with the highest VIF to reduce redundancy.

# %%
combined_prices.drop(columns=['Copper_Price'], inplace=True)

# %%
X = combined_prices.drop(columns=['Gold_Price'])  
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif_data)
# Out:
#                  feature        VIF
# 0              USO_Price   3.590387
# 1              S&P_Price  11.606369
# 2           Silver_Price   9.377160
# 3  US_Dollor_Index_Price  21.709654

# %% [markdown]
# So now let's remove the US_Dollor_Index_Price  feature with the highest VIF

# %%
combined_prices.drop(columns=['US_Dollor_Index_Price'], inplace=True)

# %%
X = combined_prices.drop(columns=['Gold_Price'])  
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print(vif_data)
# Out:
#         feature       VIF
# 0     USO_Price  2.336134
# 1     S&P_Price  4.995812
# 2  Silver_Price  7.582580

# %%
combined_prices
# Out:
#             USO_Price  S&P_Price  Gold_Price  Silver_Price
# Date
# 2006-04-11     545.60    1286.60     599.400       12.6000
# 2006-04-12     542.72    1288.10     601.300       12.6630
# 2006-04-13     550.56    1289.10     600.100       12.8550
# 2006-04-14     552.50    1288.15     604.775       12.9825
# 2006-04-15     554.44    1287.20     609.450       13.1100
# ...               ...        ...         ...           ...
# 2024-08-19      74.38    5608.25    2541.300       29.7320
# 2024-08-20      73.83    5597.12    2550.600       29.9530
# 2024-08-21      72.60    5620.85    2547.500       29.9710
# 2024-08-22      73.58    5570.64    2516.700       29.4710
# 2024-08-23      75.55    5634.61    2546.300       30.2560
#
# [6710 rows x 4 columns]
